# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name: Bardia Mandegar
# Student-ID: 401170637

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)


def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# -------------------------------- TODO -------------------------------------
# In this section, split the data into training and test datasets, using 60,000 samples for training and the remaining samples for testing.
x_train, x_test, y_train, y_test = train_test_split(x, y_new, test_size=10000, random_state=SEED)
# -------------------------------- TODO -------------------------------------

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'tanh':
            self.activation = self.tanh
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        # -------------------------------- TODO -------------------------------------
        # Do the same for other activation functions
        elif activation == 'softmax':
            self.activation = self.softmax
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu
        # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}


    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x <= 0, 0, 1)
        else:
            return np.maximum(0, x)
        # -------------------------------- TODO -------------------------------------


    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return 1 - np.tanh(x) ** 2
        else:
            return np.tanh(x)
        # -------------------------------- TODO -------------------------------------


    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.exp(-x) / (1 + np.exp(-x)) ** 2
        else:
            return 1 / (1 + np.exp(-x))
        # -------------------------------- TODO -------------------------------------


    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        # -------------------------------- TODO -------------------------------------
        return np.exp(x) / np.sum(np.exp(x), axis=0)
        # -------------------------------- TODO -------------------------------------


    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x >= 0, 1, alpha)
        else:
            return np.maximum(alpha * x, x)
        # -------------------------------- TODO -------------------------------------


    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params


    def feed_forward(self, x):
        self.cache["A0"] = x.T
        # -------------------------------- TODO -------------------------------------
        # Perform feedforward pass through each hidden layer, applying weights, biases, and activation function
        for i in range(1, self.num_layers + 1):
            self.cache[f"Z{i}"] = np.dot(self.params[f"W{i}"], self.cache[f"A{i - 1}"]) + self.params[f"b{i}"]
            self.cache[f"A{i}"] = self.activation(self.cache[f"Z{i}"])
        # -------------------------------- TODO -------------------------------------
        return self.cache[f"A{self.num_layers}"]


    def back_propagate(self, y, output):
        current_batch_size = y.shape[0]
        grads = {}
        # -------------------------------- TODO -------------------------------------
        # Backpropagate gradients through Output layer and each hidden layers
        for i in range(self.num_layers, 0, -1):
            if i == self.num_layers:
                grads[f"dZ{i}"] = output - y.T
            else:
                grads[f"dZ{i}"] = self.params[f"W{i + 1}"].T @ grads[f"dZ{i + 1}"] * self.activation(self.cache[f"Z{i}"], derivative=True)

            grads[f"dW{i}"] = np.dot(grads[f"dZ{i}"], self.cache[f"A{i - 1}"].T) / current_batch_size
            grads[f"db{i}"] = np.sum(grads[f"dZ{i}"], axis=1, keepdims=True) / current_batch_size
        # -------------------------------- TODO -------------------------------------
        self.grads = grads
        return self.grads


    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # -------------------------------- TODO -------------------------------------
        # Compute cross-entropy loss as the negative average log-likelihood of the correct labels
        # loss = 0.0
        # for i in range(y.shape[0]):
        #     for j in range(y.shape[1]):
        #         if np.abs(y[i, j] - 1) < 1e-4:
        #             loss += -np.log(self.softmax(output)[j, i] + 1e-6)
        #             break
        # return loss / y.shape[0]

        softmax_output = self.softmax(output.T)

        correct_class_probs = np.sum(y * softmax_output, axis=1)  # Select correct class probabilities

        loss = -np.mean(np.log(correct_class_probs + 1e-6))  # Add epsilon to avoid log(0)

        return loss
        # -------------------------------- TODO -------------------------------------


    def initialize_momemtum_optimizer(self):
        momemtum_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for momentum updates of weights and biases in each layer
            momemtum_opt[f"VW{i}"] = np.zeros_like(self.params[f"W{i}"])
            momemtum_opt[f"Vb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return momemtum_opt


    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for first and second moment estimates of weights and biases in each layer
            adam_opt[f"VW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"Vb{i}"] = np.zeros_like(self.params[f"b{i}"])
            adam_opt[f"SW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"Sb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return adam_opt


    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):

        if self.optimizer == "sgd":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for SGD
                self.params[key] -= l_rate * self.grads[f"d{key}"]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "momentum":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Momentum
                self.momemtum_opt[f"V{key}"] = beta * self.momemtum_opt[f"V{key}"] + (1 - beta) * self.grads[f"d{key}"]
                self.params[key] -= l_rate * self.momemtum_opt[f"V{key}"]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "adam":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Adam
                self.adam_opt[f"V{key}"] = beta1 * self.adam_opt[f"V{key}"] + (1 - beta1) * self.grads[f"d{key}"]
                self.adam_opt[f"S{key}"] = beta2 * self.adam_opt[f"S{key}"] + (1 - beta2) * self.grads[f"d{key}"] ** 2
                V_corrected = self.adam_opt[f"V{key}"] / (1 - beta1 ** t)
                S_corrected = self.adam_opt[f"S{key}"] / (1 - beta2 ** t)
                self.params[key] -= l_rate * V_corrected / (np.sqrt(S_corrected) + epsilon)
                # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code


    def accuracy(self, y, output):
        # -------------------------------- TODO -------------------------------------
        # Calculate accuracy by comparing the pred and truth matrices
        pred = np.argmax(output, axis=0)
        truth = np.argmax(y.T, axis=0)
        acc = np.mean(pred == truth)

        return acc
        # -------------------------------- TODO --------------------------------------


    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        # Train
        for i in range(self.epochs):
            # Shuffle
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                # Batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                # Forward
                output = self.feed_forward(x)
                # Backprop
                grad = self.back_propagate(y, output)
                # Optimize
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            # Evaluate performance
            # Training data
            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            # Test data
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                      f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')


    def evaluate(self, x_test, y_test):
        # Test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')
        return test_loss, test_acc

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
# Run your experiments here ...

optimizers = ['sgd', 'momentum', 'adam']
activation_functions = ['relu', 'sigmoid', 'tanh', 'leaky_relu', 'selu', 'elu']
learning_rates = [0.01, 0.001]

best_accuracy = 0
best_optimizer = None
best_activation_function = None
best_learning_rate = None

for optimizer in optimizers:
  for activation_function in activation_functions:
    for learning_rate in learning_rates:
      print(f"Optimizer: {optimizer}, Activation Function: {activation_function}, Learning Rate: {learning_rate}")
      model = MLP([784, 128, 64, 10], activation=activation_function)
      model.train(x_train, y_train, x_test, y_test, epochs=20, batch_size=64, optimizer=optimizer, l_rate=learning_rate)
      loss, accuracy = model.evaluate(x_test, y_test)
      if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_optimizer = optimizer
        best_activation_function = activation_function
        best_learning_rate = learning_rate
      print("\n")

print(f"Best test accuracy: {best_accuracy}")
print(f"Best optimizer: {best_optimizer}")
print(f"Best activation function: {best_activation_function}")
print(f"Best learning rate: {best_learning_rate}")
# Out:
# Optimizer: sgd, Activation Function: relu, Learning Rate: 0.01
# Epoch 1: 3.73s, train acc=0.86, train loss=10.44, validation acc=0.85, validation loss=8.69
# Epoch 2: 9.04s, train acc=0.90, train loss=10.36, validation acc=0.89, validation loss=8.61
# Epoch 3: 12.28s, train acc=0.92, train loss=10.33, validation acc=0.90, validation loss=8.58
# Epoch 4: 15.31s, train acc=0.92, train loss=10.31, validation acc=0.91, validation loss=8.56
# Epoch 5: 19.94s, train acc=0.93, train loss=10.29, validation acc=0.92, validation loss=8.54
# Epoch 6: 24.83s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.53
# Epoch 7: 27.88s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.52
# Epoch 8: 31.16s, train acc=0.94, train loss=10.27, validation acc=0.94, validation loss=8.52
# Epoch 9: 35.59s, train acc=0.95, train loss=10.27, validation acc=0.94, validation loss=8.51
# Epoch 10: 41.13s, train acc=0.95, train loss=10.26, validation acc=0.94, validation loss=8.50
# Epoch 11: 44.29s, train acc=0.95, train loss=10.25, validation acc=0.94, validation loss=8.50
# Epoch 12: 47.44s, train acc=0.95, train loss=10.25, validation acc=0.94, validation loss=8.49
# Epoch 13: 52.47s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.49
# Epoch 14: 56.55s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.48
# Epoch 15: 59.67s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.48
# Epoch 16: 62.78s, train acc=0.96, train loss=10.23, validation acc=0.95, validation loss=8.47
# Epoch 17: 67.47s, train acc=0.96, train loss=10.23, validation acc=0.95, validation loss=8.48
# Epoch 18: 72.09s, train acc=0.96, train loss=10.23, validation acc=0.95, validation loss=8.47
# Epoch 19: 75.16s, train acc=0.97, train loss=10.22, validation acc=0.95, validation loss=8.47
# Epoch 20: 78.34s, train acc=0.97, train loss=10.22, validation acc=0.96, validation loss=8.47
#
# Test acc=0.96, Test loss=8.47
#
#
# Optimizer: sgd, Activation Function: relu, Learning Rate: 0.001
# Epoch 1: 4.91s, train acc=0.50, train loss=10.82, validation acc=0.49, validation loss=9.07
# Epoch 2: 9.38s, train acc=0.66, train loss=10.73, validation acc=0.65, validation loss=8.98
# Epoch 3: 12.58s, train acc=0.74, train loss=10.66, validation acc=0.72, validation loss=8.90
# Epoch 4: 15.70s, train acc=0.78, train loss=10.59, validation acc=0.77, validation loss=8.84
# Epoch 5: 20.11s, train acc=0.81, train loss=10.55, validation acc=0.79, validation loss=8.79
# Epoch 6: 25.03s, train acc=0.83, train loss=10.51, validation acc=0.82, validation loss=8.76
# Epoch 7: 28.24s, train acc=0.85, train loss=10.48, validation acc=0.83, validation loss=8.73
# Epoch 8: 31.39s, train acc=0.86, train loss=10.46, validation acc=0.85, validation loss=8.71
# Epoch 9: 35.98s, train acc=0.87, train loss=10.44, validation acc=0.86, validation loss=8.69
# Epoch 10: 40.82s, train acc=0.87, train loss=10.43, validation acc=0.86, validation loss=8.67
# Epoch 11: 43.92s, train acc=0.88, train loss=10.41, validation acc=0.87, validation loss=8.66
# Epoch 12: 46.94s, train acc=0.88, train loss=10.40, validation acc=0.87, validation loss=8.65
# Epoch 13: 50.91s, train acc=0.89, train loss=10.39, validation acc=0.88, validation loss=8.64
# Epoch 14: 56.36s, train acc=0.89, train loss=10.39, validation acc=0.88, validation loss=8.63
# Epoch 15: 59.56s, train acc=0.90, train loss=10.38, validation acc=0.88, validation loss=8.62
# Epoch 16: 62.77s, train acc=0.90, train loss=10.37, validation acc=0.88, validation loss=8.62
# Epoch 17: 67.30s, train acc=0.90, train loss=10.37, validation acc=0.89, validation loss=8.61
# Epoch 18: 72.20s, train acc=0.90, train loss=10.36, validation acc=0.89, validation loss=8.61
# Epoch 19: 75.50s, train acc=0.90, train loss=10.35, validation acc=0.89, validation loss=8.60
# Epoch 20: 78.81s, train acc=0.91, train loss=10.35, validation acc=0.89, validation loss=8.60
#
# Test acc=0.89, Test loss=8.60
#
#
# Optimizer: sgd, Activation Function: sigmoid, Learning Rate: 0.01
# Epoch 1: 7.55s, train acc=0.17, train loss=10.94, validation acc=0.17, validation loss=9.20
# Epoch 2: 11.88s, train acc=0.50, train loss=10.93, validation acc=0.49, validation loss=9.19
# Epoch 3: 16.14s, train acc=0.59, train loss=10.91, validation acc=0.58, validation loss=9.17
# Epoch 4: 23.48s, train acc=0.61, train loss=10.86, validation acc=0.61, validation loss=9.11
# Epoch 5: 27.63s, train acc=0.66, train loss=10.78, validation acc=0.65, validation loss=9.03
# Epoch 6: 31.74s, train acc=0.70, train loss=10.71, validation acc=0.69, validation loss=8.96
# Epoch 7: 39.05s, train acc=0.74, train loss=10.65, validation acc=0.74, validation loss=8.90
# Epoch 8: 43.34s, train acc=0.77, train loss=10.61, validation acc=0.77, validation loss=8.85
# Epoch 9: 47.56s, train acc=0.80, train loss=10.57, validation acc=0.80, validation loss=8.81
# Epoch 10: 54.75s, train acc=0.82, train loss=10.53, validation acc=0.81, validation loss=8.78
# Epoch 11: 58.87s, train acc=0.83, train loss=10.50, validation acc=0.83, validation loss=8.75
# Epoch 12: 62.93s, train acc=0.84, train loss=10.48, validation acc=0.84, validation loss=8.72
# Epoch 13: 70.24s, train acc=0.85, train loss=10.46, validation acc=0.84, validation loss=8.70
# Epoch 14: 74.47s, train acc=0.86, train loss=10.44, validation acc=0.85, validation loss=8.68
# Epoch 15: 78.77s, train acc=0.86, train loss=10.42, validation acc=0.86, validation loss=8.67
# Epoch 16: 86.23s, train acc=0.87, train loss=10.41, validation acc=0.86, validation loss=8.65
# Epoch 17: 90.42s, train acc=0.88, train loss=10.40, validation acc=0.87, validation loss=8.64
# Epoch 18: 94.92s, train acc=0.88, train loss=10.39, validation acc=0.87, validation loss=8.63
# Epoch 19: 101.74s, train acc=0.88, train loss=10.38, validation acc=0.88, validation loss=8.62
# Epoch 20: 105.86s, train acc=0.89, train loss=10.37, validation acc=0.88, validation loss=8.61
#
# Test acc=0.88, Test loss=8.61
#
#
# Optimizer: sgd, Activation Function: sigmoid, Learning Rate: 0.001
# Epoch 1: 4.40s, train acc=0.10, train loss=10.94, validation acc=0.10, validation loss=9.20
# Epoch 2: 11.32s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 3: 15.51s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 4: 20.09s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 5: 26.55s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 6: 30.93s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 7: 36.05s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 8: 42.50s, train acc=0.14, train loss=10.94, validation acc=0.14, validation loss=9.20
# Epoch 9: 46.66s, train acc=0.13, train loss=10.94, validation acc=0.13, validation loss=9.20
# Epoch 10: 51.60s, train acc=0.14, train loss=10.94, validation acc=0.14, validation loss=9.20
# Epoch 11: 57.41s, train acc=0.17, train loss=10.94, validation acc=0.17, validation loss=9.20
# Epoch 12: 61.67s, train acc=0.17, train loss=10.94, validation acc=0.17, validation loss=9.20
# Epoch 13: 67.45s, train acc=0.20, train loss=10.94, validation acc=0.20, validation loss=9.20
# Epoch 14: 73.09s, train acc=0.26, train loss=10.94, validation acc=0.26, validation loss=9.20
# Epoch 15: 77.28s, train acc=0.28, train loss=10.94, validation acc=0.28, validation loss=9.19
# Epoch 16: 82.91s, train acc=0.28, train loss=10.94, validation acc=0.28, validation loss=9.19
# Epoch 17: 88.25s, train acc=0.31, train loss=10.94, validation acc=0.30, validation loss=9.19
# Epoch 18: 92.38s, train acc=0.33, train loss=10.94, validation acc=0.32, validation loss=9.19
# Epoch 19: 97.77s, train acc=0.35, train loss=10.94, validation acc=0.34, validation loss=9.19
# Epoch 20: 103.20s, train acc=0.35, train loss=10.93, validation acc=0.35, validation loss=9.19
#
# Test acc=0.35, Test loss=9.19
#
#
# Optimizer: sgd, Activation Function: tanh, Learning Rate: 0.01
# Epoch 1: 5.84s, train acc=0.85, train loss=10.52, validation acc=0.83, validation loss=8.77
# Epoch 2: 14.25s, train acc=0.86, train loss=10.49, validation acc=0.85, validation loss=8.73
# Epoch 3: 20.07s, train acc=0.88, train loss=10.45, validation acc=0.86, validation loss=8.70
# Epoch 4: 28.74s, train acc=0.89, train loss=10.42, validation acc=0.88, validation loss=8.66
# Epoch 5: 34.68s, train acc=0.90, train loss=10.39, validation acc=0.89, validation loss=8.63
# Epoch 6: 43.02s, train acc=0.91, train loss=10.37, validation acc=0.90, validation loss=8.61
# Epoch 7: 48.80s, train acc=0.91, train loss=10.35, validation acc=0.90, validation loss=8.59
# Epoch 8: 57.33s, train acc=0.92, train loss=10.33, validation acc=0.91, validation loss=8.58
# Epoch 9: 63.06s, train acc=0.92, train loss=10.32, validation acc=0.91, validation loss=8.57
# Epoch 10: 71.24s, train acc=0.92, train loss=10.31, validation acc=0.91, validation loss=8.56
# Epoch 11: 77.12s, train acc=0.93, train loss=10.30, validation acc=0.92, validation loss=8.55
# Epoch 12: 84.46s, train acc=0.93, train loss=10.30, validation acc=0.92, validation loss=8.54
# Epoch 13: 90.74s, train acc=0.93, train loss=10.29, validation acc=0.92, validation loss=8.54
# Epoch 14: 96.83s, train acc=0.93, train loss=10.29, validation acc=0.92, validation loss=8.53
# Epoch 15: 104.50s, train acc=0.93, train loss=10.28, validation acc=0.92, validation loss=8.52
# Epoch 16: 110.48s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.52
# Epoch 17: 118.54s, train acc=0.94, train loss=10.27, validation acc=0.93, validation loss=8.51
# Epoch 18: 124.26s, train acc=0.94, train loss=10.27, validation acc=0.93, validation loss=8.51
# Epoch 19: 132.84s, train acc=0.94, train loss=10.27, validation acc=0.93, validation loss=8.51
# Epoch 20: 138.68s, train acc=0.94, train loss=10.26, validation acc=0.93, validation loss=8.51
#
# Test acc=0.93, Test loss=8.51
#
#
# Optimizer: sgd, Activation Function: tanh, Learning Rate: 0.001
# Epoch 1: 8.63s, train acc=0.65, train loss=10.70, validation acc=0.64, validation loss=8.94
# Epoch 2: 14.42s, train acc=0.75, train loss=10.63, validation acc=0.73, validation loss=8.87
# Epoch 3: 22.85s, train acc=0.78, train loss=10.59, validation acc=0.77, validation loss=8.84
# Epoch 4: 28.63s, train acc=0.80, train loss=10.58, validation acc=0.79, validation loss=8.82
# Epoch 5: 37.31s, train acc=0.81, train loss=10.56, validation acc=0.80, validation loss=8.81
# Epoch 6: 43.00s, train acc=0.82, train loss=10.55, validation acc=0.80, validation loss=8.80
# Epoch 7: 51.44s, train acc=0.83, train loss=10.55, validation acc=0.81, validation loss=8.79
# Epoch 8: 57.31s, train acc=0.83, train loss=10.54, validation acc=0.82, validation loss=8.79
# Epoch 9: 65.01s, train acc=0.84, train loss=10.53, validation acc=0.82, validation loss=8.78
# Epoch 10: 70.94s, train acc=0.84, train loss=10.53, validation acc=0.83, validation loss=8.77
# Epoch 11: 77.37s, train acc=0.84, train loss=10.52, validation acc=0.83, validation loss=8.77
# Epoch 12: 84.38s, train acc=0.85, train loss=10.52, validation acc=0.83, validation loss=8.77
# Epoch 13: 90.17s, train acc=0.85, train loss=10.51, validation acc=0.83, validation loss=8.76
# Epoch 14: 98.76s, train acc=0.85, train loss=10.51, validation acc=0.84, validation loss=8.76
# Epoch 15: 104.55s, train acc=0.85, train loss=10.51, validation acc=0.84, validation loss=8.75
# Epoch 16: 113.15s, train acc=0.86, train loss=10.50, validation acc=0.84, validation loss=8.75
# Epoch 17: 119.03s, train acc=0.86, train loss=10.50, validation acc=0.84, validation loss=8.75
# Epoch 18: 127.49s, train acc=0.86, train loss=10.50, validation acc=0.85, validation loss=8.74
# Epoch 19: 133.21s, train acc=0.86, train loss=10.49, validation acc=0.85, validation loss=8.74
# Epoch 20: 141.88s, train acc=0.86, train loss=10.49, validation acc=0.85, validation loss=8.74
#
# Test acc=0.85, Test loss=8.74
#
#
# Optimizer: sgd, Activation Function: leaky_relu, Learning Rate: 0.01
# Epoch 1: 3.26s, train acc=0.87, train loss=10.44, validation acc=0.85, validation loss=8.69
# Epoch 2: 6.44s, train acc=0.90, train loss=10.37, validation acc=0.89, validation loss=8.61
# Epoch 3: 11.53s, train acc=0.91, train loss=10.34, validation acc=0.90, validation loss=8.59
# Epoch 4: 15.59s, train acc=0.92, train loss=10.32, validation acc=0.91, validation loss=8.57
# Epoch 5: 18.76s, train acc=0.93, train loss=10.31, validation acc=0.92, validation loss=8.55
# Epoch 6: 21.91s, train acc=0.94, train loss=10.29, validation acc=0.92, validation loss=8.54
# Epoch 7: 27.30s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.53
# Epoch 8: 30.99s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.52
# Epoch 9: 34.18s, train acc=0.95, train loss=10.27, validation acc=0.94, validation loss=8.52
# Epoch 10: 37.22s, train acc=0.95, train loss=10.26, validation acc=0.94, validation loss=8.51
# Epoch 11: 42.93s, train acc=0.95, train loss=10.26, validation acc=0.94, validation loss=8.50
# Epoch 12: 46.19s, train acc=0.96, train loss=10.25, validation acc=0.94, validation loss=8.50
# Epoch 13: 49.41s, train acc=0.96, train loss=10.25, validation acc=0.95, validation loss=8.50
# Epoch 14: 52.52s, train acc=0.96, train loss=10.25, validation acc=0.95, validation loss=8.49
# Epoch 15: 58.76s, train acc=0.96, train loss=10.25, validation acc=0.95, validation loss=8.49
# Epoch 16: 61.90s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.49
# Epoch 17: 65.16s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.48
# Epoch 18: 68.99s, train acc=0.97, train loss=10.24, validation acc=0.95, validation loss=8.48
# Epoch 19: 74.44s, train acc=0.97, train loss=10.24, validation acc=0.95, validation loss=8.48
# Epoch 20: 77.57s, train acc=0.97, train loss=10.23, validation acc=0.95, validation loss=8.48
#
# Test acc=0.95, Test loss=8.48
#
#
# Optimizer: sgd, Activation Function: leaky_relu, Learning Rate: 0.001
# Epoch 1: 3.09s, train acc=0.55, train loss=10.82, validation acc=0.54, validation loss=9.07
# Epoch 2: 7.19s, train acc=0.67, train loss=10.72, validation acc=0.66, validation loss=8.97
# Epoch 3: 12.07s, train acc=0.72, train loss=10.65, validation acc=0.71, validation loss=8.90
# Epoch 4: 15.39s, train acc=0.76, train loss=10.60, validation acc=0.74, validation loss=8.85
# Epoch 5: 18.65s, train acc=0.79, train loss=10.56, validation acc=0.77, validation loss=8.81
# Epoch 6: 23.22s, train acc=0.81, train loss=10.52, validation acc=0.80, validation loss=8.77
# Epoch 7: 27.23s, train acc=0.82, train loss=10.50, validation acc=0.81, validation loss=8.74
# Epoch 8: 30.35s, train acc=0.84, train loss=10.47, validation acc=0.82, validation loss=8.72
# Epoch 9: 33.49s, train acc=0.85, train loss=10.46, validation acc=0.84, validation loss=8.70
# Epoch 10: 38.68s, train acc=0.86, train loss=10.44, validation acc=0.85, validation loss=8.69
# Epoch 11: 42.47s, train acc=0.87, train loss=10.43, validation acc=0.85, validation loss=8.68
# Epoch 12: 45.83s, train acc=0.87, train loss=10.42, validation acc=0.86, validation loss=8.66
# Epoch 13: 49.03s, train acc=0.88, train loss=10.41, validation acc=0.87, validation loss=8.66
# Epoch 14: 54.85s, train acc=0.88, train loss=10.40, validation acc=0.87, validation loss=8.65
# Epoch 15: 58.11s, train acc=0.89, train loss=10.39, validation acc=0.87, validation loss=8.64
# Epoch 16: 61.30s, train acc=0.89, train loss=10.39, validation acc=0.88, validation loss=8.63
# Epoch 17: 64.53s, train acc=0.89, train loss=10.38, validation acc=0.88, validation loss=8.63
# Epoch 18: 70.61s, train acc=0.90, train loss=10.38, validation acc=0.88, validation loss=8.62
# Epoch 19: 73.80s, train acc=0.90, train loss=10.37, validation acc=0.88, validation loss=8.62
# Epoch 20: 77.11s, train acc=0.90, train loss=10.37, validation acc=0.89, validation loss=8.61
#
# Test acc=0.89, Test loss=8.61
#
#
# Optimizer: sgd, Activation Function: selu, Learning Rate: 0.01
# Epoch 1: 4.99s, train acc=0.85, train loss=10.49, validation acc=0.84, validation loss=8.74
# Epoch 2: 10.62s, train acc=0.88, train loss=10.45, validation acc=0.86, validation loss=8.70
# Epoch 3: 14.63s, train acc=0.89, train loss=10.42, validation acc=0.88, validation loss=8.67
# Epoch 4: 19.12s, train acc=0.91, train loss=10.40, validation acc=0.89, validation loss=8.64
# Epoch 5: 25.40s, train acc=0.91, train loss=10.38, validation acc=0.90, validation loss=8.62
# Epoch 6: 29.65s, train acc=0.91, train loss=10.36, validation acc=0.90, validation loss=8.60
# Epoch 7: 34.22s, train acc=0.92, train loss=10.35, validation acc=0.91, validation loss=8.59
# Epoch 8: 40.25s, train acc=0.92, train loss=10.33, validation acc=0.91, validation loss=8.58
# Epoch 9: 44.36s, train acc=0.92, train loss=10.33, validation acc=0.91, validation loss=8.58
# Epoch 10: 49.02s, train acc=0.93, train loss=10.33, validation acc=0.92, validation loss=8.57
# Epoch 11: 54.96s, train acc=0.93, train loss=10.32, validation acc=0.92, validation loss=8.56
# Epoch 12: 59.05s, train acc=0.93, train loss=10.31, validation acc=0.92, validation loss=8.56
# Epoch 13: 63.62s, train acc=0.93, train loss=10.31, validation acc=0.92, validation loss=8.55
# Epoch 14: 69.78s, train acc=0.94, train loss=10.30, validation acc=0.92, validation loss=8.55
# Epoch 15: 73.69s, train acc=0.94, train loss=10.30, validation acc=0.93, validation loss=8.55
# Epoch 16: 77.88s, train acc=0.94, train loss=10.29, validation acc=0.92, validation loss=8.54
# Epoch 17: 84.55s, train acc=0.94, train loss=10.29, validation acc=0.92, validation loss=8.54
# Epoch 18: 88.68s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.53
# Epoch 19: 92.85s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.53
# Epoch 20: 100.05s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.53
#
# Test acc=0.93, Test loss=8.53
#
#
# Optimizer: sgd, Activation Function: selu, Learning Rate: 0.001
# Epoch 1: 4.17s, train acc=0.70, train loss=10.59, validation acc=0.68, validation loss=8.84
# Epoch 2: 8.64s, train acc=0.77, train loss=10.55, validation acc=0.76, validation loss=8.80
# Epoch 3: 14.34s, train acc=0.80, train loss=10.54, validation acc=0.79, validation loss=8.78
# Epoch 4: 18.72s, train acc=0.82, train loss=10.52, validation acc=0.80, validation loss=8.77
# Epoch 5: 29.50s, train acc=0.83, train loss=10.52, validation acc=0.82, validation loss=8.76
# Epoch 6: 33.69s, train acc=0.84, train loss=10.51, validation acc=0.82, validation loss=8.76
# Epoch 7: 37.67s, train acc=0.84, train loss=10.50, validation acc=0.83, validation loss=8.75
# Epoch 8: 44.59s, train acc=0.85, train loss=10.50, validation acc=0.83, validation loss=8.74
# Epoch 9: 48.63s, train acc=0.85, train loss=10.49, validation acc=0.83, validation loss=8.74
# Epoch 10: 52.54s, train acc=0.86, train loss=10.49, validation acc=0.84, validation loss=8.74
# Epoch 11: 59.77s, train acc=0.86, train loss=10.48, validation acc=0.84, validation loss=8.73
# Epoch 12: 63.70s, train acc=0.86, train loss=10.48, validation acc=0.85, validation loss=8.73
# Epoch 13: 67.78s, train acc=0.87, train loss=10.48, validation acc=0.85, validation loss=8.72
# Epoch 14: 74.73s, train acc=0.87, train loss=10.47, validation acc=0.85, validation loss=8.72
# Epoch 15: 78.90s, train acc=0.87, train loss=10.47, validation acc=0.85, validation loss=8.72
# Epoch 16: 83.18s, train acc=0.87, train loss=10.46, validation acc=0.86, validation loss=8.71
# Epoch 17: 90.76s, train acc=0.87, train loss=10.46, validation acc=0.86, validation loss=8.71
# Epoch 18: 94.68s, train acc=0.88, train loss=10.46, validation acc=0.86, validation loss=8.71
# Epoch 19: 98.90s, train acc=0.88, train loss=10.46, validation acc=0.86, validation loss=8.70
# Epoch 20: 105.53s, train acc=0.88, train loss=10.45, validation acc=0.87, validation loss=8.70
#
# Test acc=0.87, Test loss=8.70
#
#
# Optimizer: sgd, Activation Function: elu, Learning Rate: 0.01
# Epoch 1: 3.99s, train acc=0.85, train loss=10.50, validation acc=0.83, validation loss=8.75
# Epoch 2: 8.20s, train acc=0.87, train loss=10.47, validation acc=0.85, validation loss=8.72
# Epoch 3: 14.99s, train acc=0.88, train loss=10.44, validation acc=0.87, validation loss=8.68
# Epoch 4: 19.07s, train acc=0.90, train loss=10.41, validation acc=0.88, validation loss=8.66
# Epoch 5: 23.40s, train acc=0.90, train loss=10.39, validation acc=0.89, validation loss=8.64
# Epoch 6: 29.89s, train acc=0.91, train loss=10.38, validation acc=0.90, validation loss=8.62
# Epoch 7: 34.11s, train acc=0.91, train loss=10.36, validation acc=0.90, validation loss=8.61
# Epoch 8: 38.14s, train acc=0.92, train loss=10.35, validation acc=0.91, validation loss=8.59
# Epoch 9: 44.89s, train acc=0.92, train loss=10.34, validation acc=0.91, validation loss=8.59
# Epoch 10: 48.88s, train acc=0.93, train loss=10.33, validation acc=0.91, validation loss=8.58
# Epoch 11: 52.96s, train acc=0.93, train loss=10.33, validation acc=0.92, validation loss=8.57
# Epoch 12: 59.75s, train acc=0.93, train loss=10.32, validation acc=0.92, validation loss=8.57
# Epoch 13: 63.86s, train acc=0.93, train loss=10.31, validation acc=0.92, validation loss=8.56
# Epoch 14: 67.86s, train acc=0.94, train loss=10.31, validation acc=0.92, validation loss=8.56
# Epoch 15: 74.42s, train acc=0.94, train loss=10.31, validation acc=0.92, validation loss=8.55
# Epoch 16: 78.47s, train acc=0.94, train loss=10.30, validation acc=0.93, validation loss=8.55
# Epoch 17: 82.63s, train acc=0.94, train loss=10.30, validation acc=0.93, validation loss=8.54
# Epoch 18: 89.24s, train acc=0.94, train loss=10.30, validation acc=0.93, validation loss=8.54
# Epoch 19: 93.22s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.54
# Epoch 20: 97.60s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.53
#
# Test acc=0.93, Test loss=8.53
#
#
# Optimizer: sgd, Activation Function: elu, Learning Rate: 0.001
# Epoch 1: 6.49s, train acc=0.67, train loss=10.66, validation acc=0.66, validation loss=8.91
# Epoch 2: 10.47s, train acc=0.76, train loss=10.60, validation acc=0.75, validation loss=8.85
# Epoch 3: 14.84s, train acc=0.79, train loss=10.57, validation acc=0.78, validation loss=8.82
# Epoch 4: 21.39s, train acc=0.81, train loss=10.55, validation acc=0.79, validation loss=8.80
# Epoch 5: 25.47s, train acc=0.82, train loss=10.54, validation acc=0.80, validation loss=8.79
# Epoch 6: 29.68s, train acc=0.83, train loss=10.53, validation acc=0.81, validation loss=8.78
# Epoch 7: 36.54s, train acc=0.83, train loss=10.52, validation acc=0.82, validation loss=8.77
# Epoch 8: 40.50s, train acc=0.84, train loss=10.51, validation acc=0.82, validation loss=8.76
# Epoch 9: 44.34s, train acc=0.84, train loss=10.51, validation acc=0.83, validation loss=8.76
# Epoch 10: 51.24s, train acc=0.85, train loss=10.50, validation acc=0.83, validation loss=8.75
# Epoch 11: 55.23s, train acc=0.85, train loss=10.50, validation acc=0.83, validation loss=8.74
# Epoch 12: 59.47s, train acc=0.85, train loss=10.49, validation acc=0.84, validation loss=8.74
# Epoch 13: 66.53s, train acc=0.86, train loss=10.49, validation acc=0.84, validation loss=8.74
# Epoch 14: 70.56s, train acc=0.86, train loss=10.49, validation acc=0.84, validation loss=8.73
# Epoch 15: 74.71s, train acc=0.86, train loss=10.48, validation acc=0.84, validation loss=8.73
# Epoch 16: 81.44s, train acc=0.86, train loss=10.48, validation acc=0.85, validation loss=8.73
# Epoch 17: 85.38s, train acc=0.87, train loss=10.48, validation acc=0.85, validation loss=8.72
# Epoch 18: 89.41s, train acc=0.87, train loss=10.47, validation acc=0.85, validation loss=8.72
# Epoch 19: 96.49s, train acc=0.87, train loss=10.47, validation acc=0.85, validation loss=8.72
# Epoch 20: 100.66s, train acc=0.87, train loss=10.47, validation acc=0.85, validation loss=8.71
#
# Test acc=0.85, Test loss=8.71
#
#
# Optimizer: momentum, Activation Function: relu, Learning Rate: 0.01
# Epoch 1: 3.65s, train acc=0.87, train loss=10.42, validation acc=0.86, validation loss=8.66
# Epoch 2: 10.31s, train acc=0.90, train loss=10.35, validation acc=0.89, validation loss=8.60
# Epoch 3: 14.02s, train acc=0.92, train loss=10.32, validation acc=0.91, validation loss=8.57
# Epoch 4: 17.89s, train acc=0.93, train loss=10.31, validation acc=0.92, validation loss=8.55
# Epoch 5: 24.58s, train acc=0.93, train loss=10.29, validation acc=0.92, validation loss=8.54
# Epoch 6: 28.08s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.52
# Epoch 7: 31.66s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.52
# Epoch 8: 36.74s, train acc=0.95, train loss=10.27, validation acc=0.94, validation loss=8.51
# Epoch 9: 41.76s, train acc=0.95, train loss=10.26, validation acc=0.94, validation loss=8.51
# Epoch 10: 45.64s, train acc=0.95, train loss=10.25, validation acc=0.94, validation loss=8.50
# Epoch 11: 49.37s, train acc=0.96, train loss=10.25, validation acc=0.94, validation loss=8.49
# Epoch 12: 55.81s, train acc=0.96, train loss=10.25, validation acc=0.95, validation loss=8.49
# Epoch 13: 59.41s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.48
# Epoch 14: 63.31s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.48
# Epoch 15: 69.52s, train acc=0.96, train loss=10.23, validation acc=0.95, validation loss=8.48
# Epoch 16: 73.27s, train acc=0.96, train loss=10.23, validation acc=0.95, validation loss=8.47
# Epoch 17: 77.33s, train acc=0.96, train loss=10.23, validation acc=0.95, validation loss=8.47
# Epoch 18: 84.18s, train acc=0.97, train loss=10.23, validation acc=0.95, validation loss=8.47
# Epoch 19: 87.92s, train acc=0.97, train loss=10.22, validation acc=0.95, validation loss=8.47
# Epoch 20: 91.79s, train acc=0.97, train loss=10.22, validation acc=0.95, validation loss=8.47
#
# Test acc=0.95, Test loss=8.47
#
#
# Optimizer: momentum, Activation Function: relu, Learning Rate: 0.001
# Epoch 1: 5.92s, train acc=0.53, train loss=10.83, validation acc=0.53, validation loss=9.08
# Epoch 2: 9.81s, train acc=0.67, train loss=10.73, validation acc=0.66, validation loss=8.98
# Epoch 3: 13.51s, train acc=0.75, train loss=10.66, validation acc=0.73, validation loss=8.91
# Epoch 4: 17.40s, train acc=0.79, train loss=10.60, validation acc=0.77, validation loss=8.85
# Epoch 5: 23.53s, train acc=0.81, train loss=10.55, validation acc=0.80, validation loss=8.80
# Epoch 6: 27.22s, train acc=0.83, train loss=10.52, validation acc=0.82, validation loss=8.77
# Epoch 7: 30.99s, train acc=0.84, train loss=10.49, validation acc=0.83, validation loss=8.74
# Epoch 8: 37.47s, train acc=0.85, train loss=10.47, validation acc=0.84, validation loss=8.71
# Epoch 9: 41.18s, train acc=0.86, train loss=10.45, validation acc=0.85, validation loss=8.70
# Epoch 10: 45.20s, train acc=0.87, train loss=10.43, validation acc=0.86, validation loss=8.68
# Epoch 11: 51.73s, train acc=0.88, train loss=10.42, validation acc=0.86, validation loss=8.67
# Epoch 12: 55.49s, train acc=0.88, train loss=10.41, validation acc=0.87, validation loss=8.65
# Epoch 13: 59.09s, train acc=0.88, train loss=10.40, validation acc=0.87, validation loss=8.64
# Epoch 14: 64.69s, train acc=0.89, train loss=10.39, validation acc=0.87, validation loss=8.64
# Epoch 15: 68.89s, train acc=0.89, train loss=10.38, validation acc=0.88, validation loss=8.63
# Epoch 16: 72.79s, train acc=0.89, train loss=10.37, validation acc=0.88, validation loss=8.62
# Epoch 17: 77.22s, train acc=0.90, train loss=10.37, validation acc=0.88, validation loss=8.62
# Epoch 18: 83.03s, train acc=0.90, train loss=10.36, validation acc=0.89, validation loss=8.61
# Epoch 19: 86.83s, train acc=0.90, train loss=10.36, validation acc=0.89, validation loss=8.60
# Epoch 20: 90.60s, train acc=0.90, train loss=10.35, validation acc=0.89, validation loss=8.60
#
# Test acc=0.89, Test loss=8.60
#
#
# Optimizer: momentum, Activation Function: sigmoid, Learning Rate: 0.01
# Epoch 1: 7.76s, train acc=0.22, train loss=10.94, validation acc=0.22, validation loss=9.20
# Epoch 2: 12.27s, train acc=0.38, train loss=10.93, validation acc=0.38, validation loss=9.19
# Epoch 3: 18.25s, train acc=0.55, train loss=10.91, validation acc=0.54, validation loss=9.17
# Epoch 4: 24.18s, train acc=0.58, train loss=10.86, validation acc=0.58, validation loss=9.11
# Epoch 5: 28.88s, train acc=0.65, train loss=10.78, validation acc=0.65, validation loss=9.03
# Epoch 6: 36.20s, train acc=0.70, train loss=10.71, validation acc=0.69, validation loss=8.95
# Epoch 7: 40.59s, train acc=0.74, train loss=10.65, validation acc=0.73, validation loss=8.90
# Epoch 8: 45.10s, train acc=0.77, train loss=10.61, validation acc=0.76, validation loss=8.85
# Epoch 9: 51.94s, train acc=0.80, train loss=10.57, validation acc=0.80, validation loss=8.81
# Epoch 10: 56.61s, train acc=0.82, train loss=10.53, validation acc=0.82, validation loss=8.78
# Epoch 11: 63.14s, train acc=0.84, train loss=10.50, validation acc=0.83, validation loss=8.75
# Epoch 12: 68.58s, train acc=0.85, train loss=10.48, validation acc=0.84, validation loss=8.72
# Epoch 13: 73.46s, train acc=0.86, train loss=10.46, validation acc=0.85, validation loss=8.70
# Epoch 14: 81.18s, train acc=0.86, train loss=10.44, validation acc=0.85, validation loss=8.69
# Epoch 15: 85.88s, train acc=0.87, train loss=10.42, validation acc=0.86, validation loss=8.67
# Epoch 16: 91.33s, train acc=0.87, train loss=10.41, validation acc=0.87, validation loss=8.65
# Epoch 17: 97.62s, train acc=0.88, train loss=10.40, validation acc=0.87, validation loss=8.64
# Epoch 18: 102.28s, train acc=0.88, train loss=10.39, validation acc=0.87, validation loss=8.63
# Epoch 19: 109.84s, train acc=0.89, train loss=10.38, validation acc=0.88, validation loss=8.62
# Epoch 20: 114.55s, train acc=0.89, train loss=10.37, validation acc=0.88, validation loss=8.61
#
# Test acc=0.88, Test loss=8.61
#
#
# Optimizer: momentum, Activation Function: sigmoid, Learning Rate: 0.001
# Epoch 1: 4.61s, train acc=0.12, train loss=10.94, validation acc=0.12, validation loss=9.20
# Epoch 2: 11.91s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 3: 16.66s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 4: 23.11s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 5: 28.58s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 6: 33.15s, train acc=0.11, train loss=10.94, validation acc=0.11, validation loss=9.20
# Epoch 7: 40.40s, train acc=0.12, train loss=10.94, validation acc=0.12, validation loss=9.20
# Epoch 8: 44.80s, train acc=0.14, train loss=10.94, validation acc=0.14, validation loss=9.20
# Epoch 9: 49.54s, train acc=0.14, train loss=10.94, validation acc=0.14, validation loss=9.20
# Epoch 10: 57.17s, train acc=0.16, train loss=10.94, validation acc=0.16, validation loss=9.20
# Epoch 11: 62.01s, train acc=0.21, train loss=10.94, validation acc=0.21, validation loss=9.20
# Epoch 12: 68.50s, train acc=0.23, train loss=10.94, validation acc=0.23, validation loss=9.20
# Epoch 13: 73.83s, train acc=0.26, train loss=10.94, validation acc=0.26, validation loss=9.19
# Epoch 14: 78.82s, train acc=0.28, train loss=10.94, validation acc=0.28, validation loss=9.19
# Epoch 15: 86.59s, train acc=0.32, train loss=10.94, validation acc=0.31, validation loss=9.19
# Epoch 16: 91.20s, train acc=0.33, train loss=10.94, validation acc=0.32, validation loss=9.19
# Epoch 17: 96.39s, train acc=0.37, train loss=10.94, validation acc=0.36, validation loss=9.19
# Epoch 18: 102.66s, train acc=0.39, train loss=10.93, validation acc=0.39, validation loss=9.19
# Epoch 19: 107.28s, train acc=0.41, train loss=10.93, validation acc=0.41, validation loss=9.19
# Epoch 20: 115.04s, train acc=0.44, train loss=10.93, validation acc=0.43, validation loss=9.19
#
# Test acc=0.43, Test loss=9.19
#
#
# Optimizer: momentum, Activation Function: tanh, Learning Rate: 0.01
# Epoch 1: 6.24s, train acc=0.84, train loss=10.52, validation acc=0.83, validation loss=8.77
# Epoch 2: 14.63s, train acc=0.86, train loss=10.49, validation acc=0.85, validation loss=8.73
# Epoch 3: 21.09s, train acc=0.88, train loss=10.45, validation acc=0.86, validation loss=8.70
# Epoch 4: 30.01s, train acc=0.89, train loss=10.42, validation acc=0.88, validation loss=8.67
# Epoch 5: 36.42s, train acc=0.90, train loss=10.40, validation acc=0.89, validation loss=8.64
# Epoch 6: 45.46s, train acc=0.91, train loss=10.37, validation acc=0.90, validation loss=8.62
# Epoch 7: 51.92s, train acc=0.91, train loss=10.35, validation acc=0.90, validation loss=8.60
# Epoch 8: 61.05s, train acc=0.92, train loss=10.34, validation acc=0.90, validation loss=8.58
# Epoch 9: 67.48s, train acc=0.92, train loss=10.33, validation acc=0.91, validation loss=8.57
# Epoch 10: 76.72s, train acc=0.92, train loss=10.32, validation acc=0.91, validation loss=8.56
# Epoch 11: 83.19s, train acc=0.93, train loss=10.31, validation acc=0.91, validation loss=8.55
# Epoch 12: 92.07s, train acc=0.93, train loss=10.30, validation acc=0.92, validation loss=8.54
# Epoch 13: 98.83s, train acc=0.93, train loss=10.29, validation acc=0.92, validation loss=8.54
# Epoch 14: 108.10s, train acc=0.93, train loss=10.29, validation acc=0.92, validation loss=8.53
# Epoch 15: 115.14s, train acc=0.93, train loss=10.29, validation acc=0.92, validation loss=8.53
# Epoch 16: 123.43s, train acc=0.94, train loss=10.28, validation acc=0.92, validation loss=8.52
# Epoch 17: 130.56s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.52
# Epoch 18: 138.32s, train acc=0.94, train loss=10.27, validation acc=0.93, validation loss=8.52
# Epoch 19: 144.83s, train acc=0.94, train loss=10.27, validation acc=0.93, validation loss=8.51
# Epoch 20: 153.16s, train acc=0.94, train loss=10.27, validation acc=0.93, validation loss=8.51
#
# Test acc=0.93, Test loss=8.51
#
#
# Optimizer: momentum, Activation Function: tanh, Learning Rate: 0.001
# Epoch 1: 7.53s, train acc=0.69, train loss=10.67, validation acc=0.68, validation loss=8.92
# Epoch 2: 15.26s, train acc=0.77, train loss=10.61, validation acc=0.75, validation loss=8.86
# Epoch 3: 22.71s, train acc=0.79, train loss=10.58, validation acc=0.78, validation loss=8.83
# Epoch 4: 29.91s, train acc=0.81, train loss=10.57, validation acc=0.79, validation loss=8.82
# Epoch 5: 36.64s, train acc=0.82, train loss=10.56, validation acc=0.80, validation loss=8.80
# Epoch 6: 44.59s, train acc=0.83, train loss=10.55, validation acc=0.81, validation loss=8.80
# Epoch 7: 51.75s, train acc=0.83, train loss=10.54, validation acc=0.81, validation loss=8.79
# Epoch 8: 59.70s, train acc=0.84, train loss=10.53, validation acc=0.82, validation loss=8.78
# Epoch 9: 66.52s, train acc=0.84, train loss=10.53, validation acc=0.82, validation loss=8.78
# Epoch 10: 74.69s, train acc=0.84, train loss=10.52, validation acc=0.83, validation loss=8.77
# Epoch 11: 82.07s, train acc=0.85, train loss=10.52, validation acc=0.83, validation loss=8.77
# Epoch 12: 89.80s, train acc=0.85, train loss=10.51, validation acc=0.83, validation loss=8.76
# Epoch 13: 97.65s, train acc=0.85, train loss=10.51, validation acc=0.83, validation loss=8.76
# Epoch 14: 104.65s, train acc=0.85, train loss=10.50, validation acc=0.84, validation loss=8.75
# Epoch 15: 112.31s, train acc=0.86, train loss=10.50, validation acc=0.84, validation loss=8.75
# Epoch 16: 119.71s, train acc=0.86, train loss=10.49, validation acc=0.84, validation loss=8.74
# Epoch 17: 127.93s, train acc=0.86, train loss=10.49, validation acc=0.84, validation loss=8.74
# Epoch 18: 134.71s, train acc=0.86, train loss=10.49, validation acc=0.85, validation loss=8.73
# Epoch 19: 143.28s, train acc=0.86, train loss=10.48, validation acc=0.85, validation loss=8.73
# Epoch 20: 149.99s, train acc=0.87, train loss=10.48, validation acc=0.85, validation loss=8.73
#
# Test acc=0.85, Test loss=8.73
#
#
# Optimizer: momentum, Activation Function: leaky_relu, Learning Rate: 0.01
# Epoch 1: 3.86s, train acc=0.88, train loss=10.42, validation acc=0.87, validation loss=8.67
# Epoch 2: 10.07s, train acc=0.90, train loss=10.36, validation acc=0.89, validation loss=8.61
# Epoch 3: 13.77s, train acc=0.92, train loss=10.33, validation acc=0.91, validation loss=8.58
# Epoch 4: 17.51s, train acc=0.93, train loss=10.31, validation acc=0.91, validation loss=8.56
# Epoch 5: 24.35s, train acc=0.93, train loss=10.30, validation acc=0.92, validation loss=8.55
# Epoch 6: 28.10s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.54
# Epoch 7: 32.20s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.53
# Epoch 8: 38.72s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.52
# Epoch 9: 42.48s, train acc=0.95, train loss=10.27, validation acc=0.94, validation loss=8.52
# Epoch 10: 46.12s, train acc=0.95, train loss=10.27, validation acc=0.94, validation loss=8.51
# Epoch 11: 51.50s, train acc=0.95, train loss=10.26, validation acc=0.94, validation loss=8.51
# Epoch 12: 56.40s, train acc=0.95, train loss=10.26, validation acc=0.94, validation loss=8.50
# Epoch 13: 60.21s, train acc=0.96, train loss=10.25, validation acc=0.94, validation loss=8.50
# Epoch 14: 64.22s, train acc=0.96, train loss=10.25, validation acc=0.95, validation loss=8.49
# Epoch 15: 70.92s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.49
# Epoch 16: 74.74s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.49
# Epoch 17: 78.36s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.48
# Epoch 18: 84.90s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.48
# Epoch 19: 88.70s, train acc=0.97, train loss=10.23, validation acc=0.95, validation loss=8.48
# Epoch 20: 92.53s, train acc=0.97, train loss=10.23, validation acc=0.95, validation loss=8.48
#
# Test acc=0.95, Test loss=8.48
#
#
# Optimizer: momentum, Activation Function: leaky_relu, Learning Rate: 0.001
# Epoch 1: 6.31s, train acc=0.49, train loss=10.85, validation acc=0.49, validation loss=9.11
# Epoch 2: 10.09s, train acc=0.65, train loss=10.76, validation acc=0.65, validation loss=9.01
# Epoch 3: 13.76s, train acc=0.73, train loss=10.68, validation acc=0.71, validation loss=8.92
# Epoch 4: 18.27s, train acc=0.77, train loss=10.61, validation acc=0.76, validation loss=8.86
# Epoch 5: 24.09s, train acc=0.80, train loss=10.56, validation acc=0.79, validation loss=8.81
# Epoch 6: 27.78s, train acc=0.82, train loss=10.53, validation acc=0.81, validation loss=8.77
# Epoch 7: 31.33s, train acc=0.84, train loss=10.50, validation acc=0.83, validation loss=8.74
# Epoch 8: 38.04s, train acc=0.85, train loss=10.47, validation acc=0.84, validation loss=8.72
# Epoch 9: 41.86s, train acc=0.86, train loss=10.45, validation acc=0.85, validation loss=8.70
# Epoch 10: 45.72s, train acc=0.87, train loss=10.44, validation acc=0.86, validation loss=8.68
# Epoch 11: 52.46s, train acc=0.87, train loss=10.43, validation acc=0.86, validation loss=8.67
# Epoch 12: 56.32s, train acc=0.88, train loss=10.42, validation acc=0.87, validation loss=8.66
# Epoch 13: 60.11s, train acc=0.88, train loss=10.41, validation acc=0.87, validation loss=8.65
# Epoch 14: 65.84s, train acc=0.89, train loss=10.40, validation acc=0.88, validation loss=8.64
# Epoch 15: 70.24s, train acc=0.89, train loss=10.39, validation acc=0.88, validation loss=8.64
# Epoch 16: 74.01s, train acc=0.89, train loss=10.38, validation acc=0.88, validation loss=8.63
# Epoch 17: 78.54s, train acc=0.89, train loss=10.38, validation acc=0.89, validation loss=8.62
# Epoch 18: 84.66s, train acc=0.90, train loss=10.37, validation acc=0.89, validation loss=8.62
# Epoch 19: 88.48s, train acc=0.90, train loss=10.37, validation acc=0.89, validation loss=8.61
# Epoch 20: 92.24s, train acc=0.90, train loss=10.36, validation acc=0.89, validation loss=8.61
#
# Test acc=0.89, Test loss=8.61
#
#
# Optimizer: momentum, Activation Function: selu, Learning Rate: 0.01
# Epoch 1: 7.52s, train acc=0.86, train loss=10.48, validation acc=0.85, validation loss=8.73
# Epoch 2: 12.12s, train acc=0.88, train loss=10.45, validation acc=0.86, validation loss=8.70
# Epoch 3: 18.39s, train acc=0.89, train loss=10.43, validation acc=0.88, validation loss=8.67
# Epoch 4: 24.03s, train acc=0.90, train loss=10.40, validation acc=0.89, validation loss=8.65
# Epoch 5: 28.63s, train acc=0.91, train loss=10.38, validation acc=0.90, validation loss=8.63
# Epoch 6: 36.11s, train acc=0.92, train loss=10.36, validation acc=0.91, validation loss=8.61
# Epoch 7: 40.73s, train acc=0.92, train loss=10.35, validation acc=0.91, validation loss=8.60
# Epoch 8: 45.31s, train acc=0.92, train loss=10.34, validation acc=0.92, validation loss=8.59
# Epoch 9: 52.59s, train acc=0.93, train loss=10.33, validation acc=0.92, validation loss=8.58
# Epoch 10: 57.24s, train acc=0.93, train loss=10.32, validation acc=0.92, validation loss=8.57
# Epoch 11: 63.70s, train acc=0.93, train loss=10.32, validation acc=0.92, validation loss=8.56
# Epoch 12: 68.53s, train acc=0.93, train loss=10.31, validation acc=0.92, validation loss=8.56
# Epoch 13: 73.22s, train acc=0.93, train loss=10.31, validation acc=0.92, validation loss=8.55
# Epoch 14: 80.84s, train acc=0.94, train loss=10.30, validation acc=0.93, validation loss=8.55
# Epoch 15: 85.61s, train acc=0.94, train loss=10.30, validation acc=0.93, validation loss=8.55
# Epoch 16: 90.78s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.54
# Epoch 17: 97.30s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.54
# Epoch 18: 101.86s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.53
# Epoch 19: 109.13s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.53
# Epoch 20: 113.91s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.53
#
# Test acc=0.93, Test loss=8.53
#
#
# Optimizer: momentum, Activation Function: selu, Learning Rate: 0.001
# Epoch 1: 4.66s, train acc=0.70, train loss=10.59, validation acc=0.69, validation loss=8.84
# Epoch 2: 12.13s, train acc=0.78, train loss=10.55, validation acc=0.77, validation loss=8.80
# Epoch 3: 16.91s, train acc=0.81, train loss=10.53, validation acc=0.79, validation loss=8.78
# Epoch 4: 23.55s, train acc=0.82, train loss=10.52, validation acc=0.81, validation loss=8.76
# Epoch 5: 28.64s, train acc=0.84, train loss=10.51, validation acc=0.82, validation loss=8.76
# Epoch 6: 33.24s, train acc=0.84, train loss=10.50, validation acc=0.83, validation loss=8.75
# Epoch 7: 40.70s, train acc=0.85, train loss=10.49, validation acc=0.84, validation loss=8.74
# Epoch 8: 45.63s, train acc=0.86, train loss=10.49, validation acc=0.84, validation loss=8.73
# Epoch 9: 51.81s, train acc=0.86, train loss=10.48, validation acc=0.85, validation loss=8.73
# Epoch 10: 57.71s, train acc=0.86, train loss=10.48, validation acc=0.85, validation loss=8.72
# Epoch 11: 62.32s, train acc=0.87, train loss=10.47, validation acc=0.86, validation loss=8.72
# Epoch 12: 69.76s, train acc=0.87, train loss=10.46, validation acc=0.86, validation loss=8.71
# Epoch 13: 74.32s, train acc=0.87, train loss=10.46, validation acc=0.86, validation loss=8.71
# Epoch 14: 78.96s, train acc=0.88, train loss=10.46, validation acc=0.86, validation loss=8.70
# Epoch 15: 86.40s, train acc=0.88, train loss=10.45, validation acc=0.87, validation loss=8.70
# Epoch 16: 91.06s, train acc=0.88, train loss=10.45, validation acc=0.87, validation loss=8.70
# Epoch 17: 97.92s, train acc=0.88, train loss=10.44, validation acc=0.87, validation loss=8.69
# Epoch 18: 103.06s, train acc=0.89, train loss=10.44, validation acc=0.88, validation loss=8.69
# Epoch 19: 107.76s, train acc=0.89, train loss=10.44, validation acc=0.88, validation loss=8.68
# Epoch 20: 115.55s, train acc=0.89, train loss=10.43, validation acc=0.88, validation loss=8.68
#
# Test acc=0.88, Test loss=8.68
#
#
# Optimizer: momentum, Activation Function: elu, Learning Rate: 0.01
# Epoch 1: 4.82s, train acc=0.84, train loss=10.51, validation acc=0.83, validation loss=8.75
# Epoch 2: 10.34s, train acc=0.86, train loss=10.47, validation acc=0.85, validation loss=8.72
# Epoch 3: 16.70s, train acc=0.88, train loss=10.44, validation acc=0.87, validation loss=8.69
# Epoch 4: 21.54s, train acc=0.89, train loss=10.42, validation acc=0.88, validation loss=8.67
# Epoch 5: 29.33s, train acc=0.90, train loss=10.40, validation acc=0.89, validation loss=8.65
# Epoch 6: 34.19s, train acc=0.91, train loss=10.38, validation acc=0.90, validation loss=8.63
# Epoch 7: 39.09s, train acc=0.92, train loss=10.36, validation acc=0.90, validation loss=8.61
# Epoch 8: 45.93s, train acc=0.92, train loss=10.35, validation acc=0.91, validation loss=8.60
# Epoch 9: 50.41s, train acc=0.93, train loss=10.34, validation acc=0.91, validation loss=8.59
# Epoch 10: 57.24s, train acc=0.93, train loss=10.33, validation acc=0.92, validation loss=8.58
# Epoch 11: 62.30s, train acc=0.93, train loss=10.32, validation acc=0.92, validation loss=8.57
# Epoch 12: 66.88s, train acc=0.93, train loss=10.32, validation acc=0.92, validation loss=8.57
# Epoch 13: 74.46s, train acc=0.94, train loss=10.31, validation acc=0.92, validation loss=8.56
# Epoch 14: 79.14s, train acc=0.94, train loss=10.31, validation acc=0.93, validation loss=8.55
# Epoch 15: 83.98s, train acc=0.94, train loss=10.31, validation acc=0.93, validation loss=8.55
# Epoch 16: 90.60s, train acc=0.94, train loss=10.30, validation acc=0.93, validation loss=8.55
# Epoch 17: 95.42s, train acc=0.94, train loss=10.30, validation acc=0.93, validation loss=8.54
# Epoch 18: 103.12s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.54
# Epoch 19: 107.76s, train acc=0.95, train loss=10.29, validation acc=0.94, validation loss=8.54
# Epoch 20: 112.20s, train acc=0.95, train loss=10.29, validation acc=0.94, validation loss=8.53
#
# Test acc=0.94, Test loss=8.53
#
#
# Optimizer: momentum, Activation Function: elu, Learning Rate: 0.001
# Epoch 1: 7.58s, train acc=0.66, train loss=10.68, validation acc=0.65, validation loss=8.93
# Epoch 2: 12.47s, train acc=0.76, train loss=10.60, validation acc=0.75, validation loss=8.85
# Epoch 3: 19.05s, train acc=0.80, train loss=10.57, validation acc=0.78, validation loss=8.82
# Epoch 4: 24.43s, train acc=0.81, train loss=10.55, validation acc=0.80, validation loss=8.80
# Epoch 5: 29.33s, train acc=0.82, train loss=10.54, validation acc=0.81, validation loss=8.78
# Epoch 6: 37.18s, train acc=0.83, train loss=10.53, validation acc=0.82, validation loss=8.77
# Epoch 7: 41.96s, train acc=0.84, train loss=10.52, validation acc=0.82, validation loss=8.77
# Epoch 8: 47.89s, train acc=0.84, train loss=10.51, validation acc=0.83, validation loss=8.76
# Epoch 9: 53.79s, train acc=0.84, train loss=10.51, validation acc=0.83, validation loss=8.75
# Epoch 10: 58.29s, train acc=0.85, train loss=10.50, validation acc=0.83, validation loss=8.75
# Epoch 11: 65.22s, train acc=0.85, train loss=10.50, validation acc=0.84, validation loss=8.74
# Epoch 12: 70.22s, train acc=0.85, train loss=10.49, validation acc=0.84, validation loss=8.74
# Epoch 13: 74.97s, train acc=0.86, train loss=10.49, validation acc=0.84, validation loss=8.74
# Epoch 14: 82.52s, train acc=0.86, train loss=10.49, validation acc=0.85, validation loss=8.73
# Epoch 15: 87.23s, train acc=0.86, train loss=10.48, validation acc=0.85, validation loss=8.73
# Epoch 16: 94.02s, train acc=0.86, train loss=10.48, validation acc=0.85, validation loss=8.73
# Epoch 17: 98.98s, train acc=0.86, train loss=10.48, validation acc=0.85, validation loss=8.72
# Epoch 18: 103.81s, train acc=0.87, train loss=10.47, validation acc=0.85, validation loss=8.72
# Epoch 19: 111.14s, train acc=0.87, train loss=10.47, validation acc=0.85, validation loss=8.72
# Epoch 20: 115.74s, train acc=0.87, train loss=10.47, validation acc=0.85, validation loss=8.71
#
# Test acc=0.85, Test loss=8.71
#
#
# Optimizer: adam, Activation Function: relu, Learning Rate: 0.01
# Epoch 1: 6.82s, train acc=0.96, train loss=10.20, validation acc=0.95, validation loss=8.44
# Epoch 2: 13.03s, train acc=0.97, train loss=10.19, validation acc=0.95, validation loss=8.44
# Epoch 3: 18.01s, train acc=0.98, train loss=10.19, validation acc=0.96, validation loss=8.44
# Epoch 4: 25.83s, train acc=0.98, train loss=10.19, validation acc=0.96, validation loss=8.43
# Epoch 5: 30.97s, train acc=0.98, train loss=10.17, validation acc=0.96, validation loss=8.41
# Epoch 6: 38.91s, train acc=0.98, train loss=10.17, validation acc=0.96, validation loss=8.42
# ...
#
# Test acc=0.97, Test loss=8.41
#
#
# Optimizer: adam, Activation Function: tanh, Learning Rate: 0.01
# Epoch 1: 10.72s, train acc=0.94, train loss=10.24, validation acc=0.93, validation loss=8.49
# Epoch 2: 19.35s, train acc=0.95, train loss=10.21, validation acc=0.94, validation loss=8.46
# Epoch 3: 28.68s, train acc=0.96, train loss=10.20, validation acc=0.94, validation loss=8.45
# Epoch 4: 39.52s, train acc=0.97, train loss=10.20, validation acc=0.95, validation loss=8.44
# Epoch 5: 47.10s, train acc=0.97, train loss=10.19, validation acc=0.95, validation loss=8.43
# Epoch 6: 57.44s, train acc=0.97, train loss=10.18, validation acc=0.95, validation loss=8.43
# Epoch 7: 67.72s, train acc=0.97, train loss=10.18, validation acc=0.96, validation loss=8.43
# Epoch 8: 75.56s, train acc=0.98, train loss=10.18, validation acc=0.95, validation loss=8.43
# Epoch 9: 86.10s, train acc=0.98, train loss=10.17, validation acc=0.95, validation loss=8.42
# Epoch 10: 95.13s, train acc=0.98, train loss=10.17, validation acc=0.95, validation loss=8.42
# Epoch 11: 103.52s, train acc=0.98, train loss=10.17, validation acc=0.96, validation loss=8.42
# Epoch 12: 114.09s, train acc=0.98, train loss=10.17, validation acc=0.95, validation loss=8.42
# Epoch 13: 122.54s, train acc=0.98, train loss=10.18, validation acc=0.95, validation loss=8.43
# Epoch 14: 132.16s, train acc=0.98, train loss=10.16, validation acc=0.95, validation loss=8.41
# Epoch 15: 142.55s, train acc=0.98, train loss=10.17, validation acc=0.95, validation loss=8.43
# Epoch 16: 150.30s, train acc=0.99, train loss=10.17, validation acc=0.96, validation loss=8.42
# Epoch 17: 160.58s, train acc=0.98, train loss=10.17, validation acc=0.95, validation loss=8.42
# Epoch 18: 170.84s, train acc=0.99, train loss=10.16, validation acc=0.96, validation loss=8.42
# Epoch 19: 178.54s, train acc=0.98, train loss=10.16, validation acc=0.96, validation loss=8.42
# Epoch 20: 188.91s, train acc=0.98, train loss=10.16, validation acc=0.95, validation loss=8.42
#
# Test acc=0.95, Test loss=8.42
#
#
# Optimizer: adam, Activation Function: tanh, Learning Rate: 0.001
# Epoch 1: 9.07s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.53
# Epoch 2: 17.68s, train acc=0.95, train loss=10.24, validation acc=0.94, validation loss=8.49
# Epoch 3: 28.39s, train acc=0.96, train loss=10.23, validation acc=0.95, validation loss=8.47
# Epoch 4: 36.11s, train acc=0.96, train loss=10.22, validation acc=0.95, validation loss=8.46
# Epoch 5: 46.33s, train acc=0.97, train loss=10.20, validation acc=0.95, validation loss=8.44
# Epoch 6: 56.43s, train acc=0.97, train loss=10.20, validation acc=0.96, validation loss=8.44
# Epoch 7: 64.25s, train acc=0.97, train loss=10.20, validation acc=0.96, validation loss=8.44
# Epoch 8: 74.77s, train acc=0.98, train loss=10.19, validation acc=0.96, validation loss=8.43
# Epoch 9: 84.90s, train acc=0.98, train loss=10.18, validation acc=0.96, validation loss=8.43
# Epoch 10: 92.68s, train acc=0.98, train loss=10.18, validation acc=0.97, validation loss=8.42
# Epoch 11: 102.86s, train acc=0.98, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 12: 111.29s, train acc=0.98, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 13: 120.53s, train acc=0.98, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 14: 130.88s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 15: 138.63s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.41
# Epoch 16: 149.04s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
# Epoch 17: 159.11s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
# Epoch 18: 166.86s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
# Epoch 19: 177.53s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
# Epoch 20: 185.93s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
#
# Test acc=0.97, Test loss=8.41
#
#
# Optimizer: adam, Activation Function: leaky_relu, Learning Rate: 0.01
# Epoch 1: 6.44s, train acc=0.96, train loss=10.21, validation acc=0.95, validation loss=8.46
# Epoch 2: 11.43s, train acc=0.97, train loss=10.20, validation acc=0.95, validation loss=8.44
# Epoch 3: 19.12s, train acc=0.98, train loss=10.17, validation acc=0.96, validation loss=8.42
# Epoch 4: 24.21s, train acc=0.98, train loss=10.17, validation acc=0.96, validation loss=8.42
# Epoch 5: 31.68s, train acc=0.98, train loss=10.17, validation acc=0.96, validation loss=8.42
# Epoch 6: 37.00s, train acc=0.98, train loss=10.18, validation acc=0.96, validation loss=8.43
# Epoch 7: 41.98s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
# Epoch 8: 49.71s, train acc=0.99, train loss=10.16, validation acc=0.96, validation loss=8.41
# Epoch 9: 54.45s, train acc=0.99, train loss=10.17, validation acc=0.96, validation loss=8.42
# Epoch 10: 60.72s, train acc=0.99, train loss=10.17, validation acc=0.96, validation loss=8.42
# Epoch 11: 67.04s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.42
# Epoch 12: 72.05s, train acc=0.99, train loss=10.16, validation acc=0.96, validation loss=8.41
# Epoch 13: 79.87s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 14: 85.46s, train acc=0.99, train loss=10.15, validation acc=0.97, validation loss=8.40
# Epoch 15: 93.11s, train acc=0.99, train loss=10.15, validation acc=0.96, validation loss=8.41
# Epoch 16: 97.90s, train acc=0.99, train loss=10.16, validation acc=0.96, validation loss=8.42
# Epoch 17: 102.72s, train acc=0.99, train loss=10.16, validation acc=0.96, validation loss=8.41
# Epoch 18: 110.36s, train acc=0.99, train loss=10.15, validation acc=0.96, validation loss=8.40
# Epoch 19: 115.28s, train acc=0.99, train loss=10.15, validation acc=0.97, validation loss=8.41
# Epoch 20: 122.96s, train acc=0.99, train loss=10.15, validation acc=0.97, validation loss=8.41
#
# Test acc=0.97, Test loss=8.41
#
#
# Optimizer: adam, Activation Function: leaky_relu, Learning Rate: 0.001
# Epoch 1: 5.04s, train acc=0.97, train loss=10.21, validation acc=0.96, validation loss=8.45
# Epoch 2: 10.22s, train acc=0.98, train loss=10.20, validation acc=0.96, validation loss=8.45
# Epoch 3: 17.67s, train acc=0.98, train loss=10.18, validation acc=0.97, validation loss=8.42
# Epoch 4: 22.84s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 5: 30.63s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 6: 35.69s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 7: 41.81s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 8: 48.58s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
# Epoch 9: 53.50s, train acc=0.99, train loss=10.15, validation acc=0.98, validation loss=8.41
# Epoch 10: 61.29s, train acc=1.00, train loss=10.15, validation acc=0.98, validation loss=8.41
# Epoch 11: 66.34s, train acc=1.00, train loss=10.15, validation acc=0.98, validation loss=8.41
# Epoch 12: 73.09s, train acc=1.00, train loss=10.15, validation acc=0.98, validation loss=8.41
# Epoch 13: 79.40s, train acc=1.00, train loss=10.15, validation acc=0.98, validation loss=8.41
# Epoch 14: 84.34s, train acc=1.00, train loss=10.16, validation acc=0.98, validation loss=8.41
# Epoch 15: 92.17s, train acc=1.00, train loss=10.15, validation acc=0.98, validation loss=8.41
# Epoch 16: 96.99s, train acc=1.00, train loss=10.15, validation acc=0.98, validation loss=8.40
# Epoch 17: 104.35s, train acc=1.00, train loss=10.15, validation acc=0.98, validation loss=8.40
# Epoch 18: 109.53s, train acc=1.00, train loss=10.15, validation acc=0.98, validation loss=8.40
# Epoch 19: 114.61s, train acc=1.00, train loss=10.15, validation acc=0.98, validation loss=8.41
# Epoch 20: 122.35s, train acc=1.00, train loss=10.14, validation acc=0.98, validation loss=8.40
#
# Test acc=0.98, Test loss=8.40
#
#
# Optimizer: adam, Activation Function: selu, Learning Rate: 0.01
# Epoch 1: 6.13s, train acc=0.91, train loss=10.35, validation acc=0.90, validation loss=8.60
# Epoch 2: 14.85s, train acc=0.93, train loss=10.28, validation acc=0.92, validation loss=8.52
# Epoch 3: 20.91s, train acc=0.94, train loss=10.24, validation acc=0.93, validation loss=8.49
# Epoch 4: 29.62s, train acc=0.95, train loss=10.23, validation acc=0.94, validation loss=8.48
# Epoch 5: 35.34s, train acc=0.96, train loss=10.24, validation acc=0.94, validation loss=8.49
# Epoch 6: 44.32s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.48
# Epoch 7: 50.48s, train acc=0.97, train loss=10.22, validation acc=0.96, validation loss=8.47
# Epoch 8: 59.12s, train acc=0.97, train loss=10.21, validation acc=0.96, validation loss=8.45
# Epoch 9: 64.94s, train acc=0.98, train loss=10.20, validation acc=0.96, validation loss=8.45
# Epoch 10: 73.09s, train acc=0.98, train loss=10.20, validation acc=0.96, validation loss=8.45
# Epoch 11: 79.46s, train acc=0.98, train loss=10.20, validation acc=0.96, validation loss=8.45
# Epoch 12: 87.96s, train acc=0.98, train loss=10.19, validation acc=0.97, validation loss=8.43
# Epoch 13: 94.30s, train acc=0.98, train loss=10.18, validation acc=0.97, validation loss=8.43
# Epoch 14: 103.66s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.42
# Epoch 15: 109.59s, train acc=0.99, train loss=10.18, validation acc=0.97, validation loss=8.43
# Epoch 16: 117.16s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
# Epoch 17: 123.98s, train acc=0.99, train loss=10.20, validation acc=0.97, validation loss=8.45
# Epoch 18: 130.85s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 19: 138.22s, train acc=0.99, train loss=10.18, validation acc=0.97, validation loss=8.43
# Epoch 20: 143.95s, train acc=0.99, train loss=10.18, validation acc=0.97, validation loss=8.44
#
# Test acc=0.97, Test loss=8.44
#
#
# Optimizer: adam, Activation Function: selu, Learning Rate: 0.001
# Epoch 1: 8.28s, train acc=0.92, train loss=10.36, validation acc=0.90, validation loss=8.61
# Epoch 2: 14.17s, train acc=0.94, train loss=10.30, validation acc=0.92, validation loss=8.55
# Epoch 3: 22.56s, train acc=0.94, train loss=10.28, validation acc=0.93, validation loss=8.53
# Epoch 4: 28.23s, train acc=0.95, train loss=10.27, validation acc=0.93, validation loss=8.51
# Epoch 5: 36.59s, train acc=0.95, train loss=10.26, validation acc=0.94, validation loss=8.51
# Epoch 6: 42.51s, train acc=0.96, train loss=10.24, validation acc=0.94, validation loss=8.49
# Epoch 7: 51.00s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.49
# Epoch 8: 57.12s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.49
# Epoch 9: 65.68s, train acc=0.97, train loss=10.23, validation acc=0.95, validation loss=8.48
# Epoch 10: 71.48s, train acc=0.97, train loss=10.23, validation acc=0.95, validation loss=8.48
# Epoch 11: 80.08s, train acc=0.97, train loss=10.22, validation acc=0.95, validation loss=8.47
# Epoch 12: 85.81s, train acc=0.97, train loss=10.22, validation acc=0.95, validation loss=8.47
# Epoch 13: 92.96s, train acc=0.97, train loss=10.22, validation acc=0.95, validation loss=8.46
# Epoch 14: 99.51s, train acc=0.97, train loss=10.21, validation acc=0.96, validation loss=8.46
# Epoch 15: 106.65s, train acc=0.97, train loss=10.22, validation acc=0.96, validation loss=8.47
# Epoch 16: 113.91s, train acc=0.97, train loss=10.20, validation acc=0.96, validation loss=8.45
# Epoch 17: 120.00s, train acc=0.97, train loss=10.21, validation acc=0.96, validation loss=8.46
# Epoch 18: 128.06s, train acc=0.98, train loss=10.21, validation acc=0.96, validation loss=8.46
# Epoch 19: 134.14s, train acc=0.98, train loss=10.21, validation acc=0.96, validation loss=8.45
# Epoch 20: 142.75s, train acc=0.98, train loss=10.20, validation acc=0.96, validation loss=8.45
#
# Test acc=0.96, Test loss=8.45
#
#
# Optimizer: adam, Activation Function: elu, Learning Rate: 0.01
# Epoch 1: 5.65s, train acc=0.94, train loss=10.26, validation acc=0.93, validation loss=8.50
# Epoch 2: 13.79s, train acc=0.96, train loss=10.24, validation acc=0.95, validation loss=8.49
# Epoch 3: 19.48s, train acc=0.97, train loss=10.20, validation acc=0.95, validation loss=8.44
# Epoch 4: 27.78s, train acc=0.98, train loss=10.21, validation acc=0.96, validation loss=8.46
# Epoch 5: 33.87s, train acc=0.98, train loss=10.18, validation acc=0.97, validation loss=8.43
# Epoch 6: 41.86s, train acc=0.98, train loss=10.19, validation acc=0.97, validation loss=8.44
# Epoch 7: 47.36s, train acc=0.99, train loss=10.15, validation acc=0.97, validation loss=8.40
# Epoch 8: 55.80s, train acc=0.99, train loss=10.20, validation acc=0.97, validation loss=8.45
# Epoch 9: 61.49s, train acc=0.99, train loss=10.15, validation acc=0.97, validation loss=8.40
# Epoch 10: 69.02s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
# Epoch 11: 75.25s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 12: 81.16s, train acc=0.99, train loss=10.18, validation acc=0.97, validation loss=8.43
# Epoch 13: 88.91s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 14: 94.75s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
# Epoch 15: 103.12s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.42
# Epoch 16: 108.86s, train acc=0.99, train loss=10.17, validation acc=0.97, validation loss=8.42
# Epoch 17: 117.11s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.42
# Epoch 18: 122.64s, train acc=0.99, train loss=10.16, validation acc=0.97, validation loss=8.41
# Epoch 19: 130.91s, train acc=1.00, train loss=10.15, validation acc=0.97, validation loss=8.41
# Epoch 20: 136.76s, train acc=1.00, train loss=10.14, validation acc=0.97, validation loss=8.40
#
# Test acc=0.97, Test loss=8.40
#
#
# Optimizer: adam, Activation Function: elu, Learning Rate: 0.001
# Epoch 1: 8.78s, train acc=0.94, train loss=10.29, validation acc=0.93, validation loss=8.53
# Epoch 2: 14.76s, train acc=0.96, train loss=10.26, validation acc=0.95, validation loss=8.51
# Epoch 3: 22.89s, train acc=0.96, train loss=10.25, validation acc=0.95, validation loss=8.50
# Epoch 4: 28.70s, train acc=0.97, train loss=10.23, validation acc=0.96, validation loss=8.47
# Epoch 5: 36.70s, train acc=0.97, train loss=10.22, validation acc=0.96, validation loss=8.47
# Epoch 6: 42.49s, train acc=0.97, train loss=10.22, validation acc=0.96, validation loss=8.46
# Epoch 7: 49.49s, train acc=0.97, train loss=10.21, validation acc=0.96, validation loss=8.46
# Epoch 8: 56.68s, train acc=0.98, train loss=10.21, validation acc=0.96, validation loss=8.45
# Epoch 9: 62.32s, train acc=0.98, train loss=10.20, validation acc=0.96, validation loss=8.45
# Epoch 10: 70.14s, train acc=0.98, train loss=10.20, validation acc=0.97, validation loss=8.45
# Epoch 11: 75.95s, train acc=0.98, train loss=10.19, validation acc=0.97, validation loss=8.44
# Epoch 12: 84.38s, train acc=0.98, train loss=10.19, validation acc=0.97, validation loss=8.44
# Epoch 13: 89.90s, train acc=0.98, train loss=10.19, validation acc=0.97, validation loss=8.44
# Epoch 14: 98.43s, train acc=0.98, train loss=10.19, validation acc=0.97, validation loss=8.44
# Epoch 15: 104.01s, train acc=0.98, train loss=10.18, validation acc=0.97, validation loss=8.43
# Epoch 16: 112.15s, train acc=0.99, train loss=10.19, validation acc=0.97, validation loss=8.43
# Epoch 17: 117.72s, train acc=0.99, train loss=10.19, validation acc=0.97, validation loss=8.43
# Epoch 18: 124.89s, train acc=0.99, train loss=10.18, validation acc=0.97, validation loss=8.43
# Epoch 19: 131.19s, train acc=0.99, train loss=10.18, validation acc=0.97, validation loss=8.43
# Epoch 20: 137.84s, train acc=0.99, train loss=10.19, validation acc=0.97, validation loss=8.44
#
# Test acc=0.97, Test loss=8.44
#
#
# Best test accuracy: 0.9767
# Best optimizer: adam
# Best activation function: leaky_relu
# Best learning rate: 0.001

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
def relu_approximation(input_data, target_labels):
    """
    Args:
      input_data: torch.tensor
        Input training data
      target_labels: torch.tensor
        Ground truth labels for training data

    Returns:
      activation_map: torch.tensor
        ReLU activations computed across the x-axis
      predicted_labels: torch.tensor
        Estimated labels or class predictions
        Derived from weighted sum of ReLU activations along the x-axis
      x_points: torch.tensor
        Points along the x-axis
    """
    ##############################---TODO---##############################
    # Number of ReLU units
    num_relus = input_data.shape[0] - 1

    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    # Compute bias for ReLU units
    biases = torch.linspace(torch.min(input_data), torch.max(input_data), num_relus + 1)[:num_relus]

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros(num_relus, x_points.shape[0])

    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])

    ## WEIGHTED SUM OF RELUS

    relu_weights = torch.zeros(num_relus)
    prev_slope = 0
    for j in range(num_relus):
        slope = (target_labels[j + 1] - target_labels[j]) / (input_data[j + 1] - input_data[j])
        relu_weights[j] = slope - prev_slope
        prev_slope = slope

    # Compute predicted labels as weighted sum of ReLU activations
    predicted_labels = relu_weights @ activation_map
    ##############################---TODO---##############################

    return predicted_labels, activation_map, x_points


# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)

predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)
plot_function_apx(x_points, activation_map, predicted_output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-cc9fac6b470f> in <cell line: 56>()
#      54
#      55 predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)
# ---> 56 plot_function_apx(x_points, activation_map, predicted_output)
#
# <ipython-input-45-797942e07a46> in plot_function_apx(x_vals, relu_activations, predicted_output)
#     246
#     247     ## Plot ReLU activations
# --> 248     axes[0].plot(x_vals, relu_activations.T)
#     249     axes[0].set_xlabel('x-values', fontsize=12)
#     250     axes[0].set_ylabel('Activation Levels', fontsize=12)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1719         """
#    1720         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722         for line in lines:
#    1723             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, axes, data, *args, **kwargs)
#     301                 this += args[0],
#     302                 args = args[1:]
# --> 303             yield from self._plot_args(
#     304                 axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     305
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     494             axes.xaxis.update_units(x)
#     495         if axes.yaxis is not None:
# --> 496             axes.yaxis.update_units(y)
#     497
#     498         if x.shape[0] != y.shape[0]:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in update_units(self, data)
#    1704         if *data* is registered for unit conversion.
#    1705         """
# -> 1706         converter = munits.registry.get_converter(data)
#    1707         if converter is None:
#    1708             return False
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/units.py in get_converter(self, x)
#     181                 pass
#     182         try:  # If cache lookup fails, look up based on first element...
# --> 183             first = cbook._safe_first_finite(x)
#     184         except (TypeError, StopIteration):
#     185             pass
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook.py in _safe_first_finite(obj, skip_nonfinite)
#    1728     else:
#    1729         for val in obj:
# -> 1730             if safe_isfinite(val):
#    1731                 return val
#    1732         return safe_first_element(obj)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook.py in safe_isfinite(val)
#    1697             return False
#    1698         try:
# -> 1699             return math.isfinite(val)
#    1700         except TypeError:
#    1701             pass
#
# ValueError: only one element tensors can be converted to Python scalars

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()

    in_num = input_feature_num
    ##############################---TODO---##############################
    for i in range(len(hidden_unit_nums)):
        self.mlp.add_module(f'Linear_{i}', nn.Linear(in_num, hidden_unit_nums[i]))
        in_num = hidden_unit_nums[i]
        self.mlp.add_module(f'Activation_{i}', getattr(nn, activation_fn)())
    out_layer = nn.Linear(in_num, output_feature_num) # final layer
    self.mlp.add_module('Output_Linear', out_layer)

    ##############################---TODO---##############################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    # Reshape inputs to (batch_size, input_feature_num)
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x) # forward pass

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ##############################---TODO---##############################
    num_features = (poly_degree + 1) * (poly_degree + 2) // 2 - 1
    poly_X = torch.zeros((X.shape[0], num_features))
    count = 0
    for i in range(poly_degree + 1):
      for j in range(poly_degree + 1):
        if i + j > 0 and i + j <= poly_degree:
          poly_X[:, count] = X[:, 0] ** i * X[:, 1] ** j
          count += 1
    return poly_X, num_features
    ##############################---TODO---##############################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                 worker_init_fn=seed_worker,
                                 generator=g_seed)

  # Defining a linear model using MLP class
  poly_net = MLP_pytorch('ReLU()', num_features, [], K)

  # Train and test
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 69.97
# Accuracy on the 800 testing samples: 69.38
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?

# %%
##############################---TODO---##############################
seed_setter(SEED)
net2 = MLP_pytorch('ReLU', 2, [128], K)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-3)
num_epochs = 100

_, _ = train_test_classification(net2, criterion, optimizer, train_loader,
                                 test_loader, num_epochs=num_epochs,
                                 training_plot=True)

X_all = sample_grid()
y_pred = net2(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 97.75
# Accuracy on the 800 testing samples: 98.00
